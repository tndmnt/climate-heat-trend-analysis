# %%
import pandas as pd

# %%
df = pd.read_csv("project_1.csv")

# %%
df.head()
# Out:
#                   time  TREFMXAV_U       FLNS       FSNS         PRECT  \
# 0  2006-01-02 00:00:00   282.77585  41.925180  25.926952  4.663135e-09
# 1  2006-01-03 00:00:00   284.47113   8.905806  10.946910  8.046593e-08
# 2  2006-01-04 00:00:00   284.28796  16.511415   6.405902  2.910936e-09
# 3  2006-01-05 00:00:00   282.12110  29.948362   9.315041  7.432505e-11
# 4  2006-01-06 00:00:00   280.89090  19.064156   7.941241  6.894238e-12
#
#            PRSN      QBOT     TREFHT      UBOT      VBOT        lat    lon
# 0  4.781004e-17  0.004769  279.14288  3.878579  1.394184  53.246075  357.5
# 1  1.295726e-16  0.006271  281.14865  1.788157  3.821703  53.246075  357.5
# 2  4.094447e-16  0.005782  281.22380  0.804845 -2.299140  53.246075  357.5
# 3  0.000000e+00  0.004277  278.39767 -1.100267 -1.258029  53.246075  357.5
# 4  0.000000e+00  0.003990  278.06378 -0.706321 -0.938421  53.246075  357.5

# %%
# TREFMXAV = daily maximum of average 2-m temperature	
# FLNS = Net longwave flux at surface
# FSNS = Net solar flux at surface
# PRECT = Total (convective and large-scale) precipitation rate (liq + ice)
# PRSN
# QBOT = Lowest model level water vapor mixing ratio
# TREFHT = Reference height temperature
# UBOT = Lowest model level zonal wind
# VBOT = Lowest model level meridional wind
# lat = latitude
# lon = longitude

# All are atmospheric measures

# %%
df.describe()
# Out:
#          TREFMXAV_U          FLNS          FSNS         PRECT          PRSN  \
# count  27374.000000  27374.000000  27374.000000  2.737400e+04  2.737400e+04
# mean     288.836179     42.995679     97.026261  3.379697e-08  3.049825e-10
# std        5.246468     21.451927     75.062880  4.986518e-08  4.706017e-09
# min      274.153200      0.611385      2.819259 -4.671764e-28 -6.256338e-21
# 25%      284.719465     26.157544     31.037187  2.131118e-09  0.000000e+00
# 50%      288.299895     40.777005     78.443183  1.311730e-08  1.206375e-21
# 75%      292.869525     57.113572    149.332133  4.637272e-08  2.348279e-16
# max      311.257260    111.851400    310.191700  7.752961e-07  2.332090e-07
#
#                QBOT        TREFHT          UBOT          VBOT           lat  \
# count  27374.000000  27374.000000  27374.000000  27374.000000  2.737400e+04
# mean       0.006523    284.876413      1.176320      1.503084  5.324608e+01
# std        0.002126      4.992277      3.066843      2.940138  1.659148e-11
# min        0.001855    268.938400     -9.739025     -8.991429  5.324607e+01
# 25%        0.004860    280.987885     -1.085982     -0.766405  5.324607e+01
# 50%        0.006211    284.537575      1.488009      1.593354  5.324607e+01
# 75%        0.007947    288.900110      3.390555      3.634500  5.324607e+01
# max        0.015222    303.117980     10.234506     11.178102  5.324607e+01
#
#            lon
# count  27374.0
# mean     357.5
# std        0.0
# min      357.5
# 25%      357.5
# 50%      357.5
# 75%      357.5
# max      357.5

# %%
import pandas as pd

# Set pandas display options to expand the column width
pd.set_option('display.max_colwidth', None)  # This will allow the full text to be displayed

# Column names
name = ['TREFMXAV_U', 'FLNS', 'FSNS', 'PRECT', 'PRSN', 'QBOT', 'TREFHT', 'UBOT', 'VBOT', 'lat', 'lon']

# Create the dataframe with 2 rows (empty values for now)
df2 = pd.DataFrame([[''] * len(name), [''] * len(name)], columns=name)

# Set the row index labels
df2.index = ['Meaning', 'Description']

# Assign specific meanings to the 'Meaning' row
meanings = [
    "daily maximum of average 2-m temperature",  
    "Net longwave flux at surface",              
    "Net solar flux at surface",                 
    "Total (convective and large-scale) precipitation rate (liq + ice)",  
    "",  
    "Lowest model level water vapor mixing ratio",  
    "Reference height temperature",              
    "Lowest model level zonal wind",             
    "Lowest model level meridional wind",        
    "latitude",                                  
    "longitude"                                  
]

# Assign descriptions to the 'Description' row
descriptions = [
    "The maximum value of the average air temperature recorded at 2 meters above the ground for a given day. It helps track how hot the air was at that height, considering temperature fluctuations during the day.",  
    "The net amount of longwave radiation energy received by the Earth's surface. Longwave radiation refers to infrared radiation, which has a longer wavelength than visible light. The Earth's surface emits longwave radiation, and this flux is a measure of the flow of this radiation. This is important for understanding the Earth's energy balance, as longwave radiation plays a key role in warming the surface and affecting the climate.",              
    "The net amount of solar radiation that reaches the Earth's surface. This flux plays a key role in warming the surface, driving weather patterns, and influencing the climate. The net solar flux accounts for both the incoming solar radiation and the portion that is reflected back into space, typically by clouds, ice, and other reflective surfaces.",  
    "Represents the total rate of precipitation falling from the atmosphere, including both liquid (rain) and ice (snow, sleet) forms, and it accounts for both convective (localized) and large-scale (widespread) weather systems.",  
    "",  
    "Represents the amount of water vapor (in terms of the mixing ratio) in the lowest layer of the atmosphere. It is an important measurement for understanding humidity levels near the Earth's surface, which affects weather patterns like cloud formation, precipitation, and temperature.",  
    "The temperature measured at a standard or reference height in the atmosphere. This is commonly used in climate models or weather forecasts to represent temperature at a specific point in the atmosphere, which helps in understanding temperature profiles and variations with altitude.",              
    "Represents the zonal wind speed and direction at the lowest model level, which is important for understanding surface-level wind patterns, especially in terms of their east-west movement. This wind component influences weather patterns, such as the movement of weather systems across regions.",             
    "Represents the meridional wind speed and direction at the lowest model level, providing information about how wind is moving in the north-south direction near the Earth's surface. This component is important for understanding large-scale atmospheric circulation and weather patterns, including the movement of air masses and systems like the jet stream.",        
    "Measures how far a point is north or south of the equator.",                                  
    "Measures how far a point is east or west of the Prime Meridian, which is located at 0° longitude."                                  
]

# Update the rows with the meanings and descriptions
df2.loc['Meaning'] = meanings
df2.loc['Description'] = descriptions

# Center-align the text in the DataFrame
df2.style.set_properties(**{'text-align': 'center'})
# Out:
# <style type="text/css">
# #T_cd678_row0_col0, #T_cd678_row0_col1, #T_cd678_row0_col2, #T_cd678_row0_col3, #T_cd678_row0_col4, #T_cd678_row0_col5, #T_cd678_row0_col6, #T_cd678_row0_col7, #T_cd678_row0_col8, #T_cd678_row0_col9, #T_cd678_row0_col10, #T_cd678_row1_col0, #T_cd678_row1_col1, #T_cd678_row1_col2, #T_cd678_row1_col3, #T_cd678_row1_col4, #T_cd678_row1_col5, #T_cd678_row1_col6, #T_cd678_row1_col7, #T_cd678_row1_col8, #T_cd678_row1_col9, #T_cd678_row1_col10 {
#   text-align: center;
# }
# </style>
# <table id="T_cd678">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd678_level0_col0" class="col_heading level0 col0" >TREFMXAV_U</th>
#       <th id="T_cd678_level0_col1" class="col_heading level0 col1" >FLNS</th>
#       <th id="T_cd678_level0_col2" class="col_heading level0 col2" >FSNS</th>
#       <th id="T_cd678_level0_col3" class="col_heading level0 col3" >PRECT</th>
#       <th id="T_cd678_level0_col4" class="col_heading level0 col4" >PRSN</th>
#       <th id="T_cd678_level0_col5" class="col_heading level0 col5" >QBOT</th>
#       <th id="T_cd678_level0_col6" class="col_heading level0 col6" >TREFHT</th>
#       <th id="T_cd678_level0_col7" class="col_heading level0 col7" >UBOT</th>
#       <th id="T_cd678_level0_col8" class="col_heading level0 col8" >VBOT</th>
#       <th id="T_cd678_level0_col9" class="col_heading level0 col9" >lat</th>
#       <th id="T_cd678_level0_col10" class="col_heading level0 col10" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd678_level0_row0" class="row_heading level0 row0" >Meaning</th>
#       <td id="T_cd678_row0_col0" class="data row0 col0" >daily maximum of average 2-m temperature</td>
#       <td id="T_cd678_row0_col1" class="data row0 col1" >Net longwave flux at surface</td>
#       <td id="T_cd678_row0_col2" class="data row0 col2" >Net solar flux at surface</td>
#       <td id="T_cd678_row0_col3" class="data row0 col3" >Total (convective and large-scale) precipitation rate (liq + ice)</td>
#       <td id="T_cd678_row0_col4" class="data row0 col4" ></td>
#       <td id="T_cd678_row0_col5" class="data row0 col5" >Lowest model level water vapor mixing ratio</td>
#       <td id="T_cd678_row0_col6" class="data row0 col6" >Reference height temperature</td>
#       <td id="T_cd678_row0_col7" class="data row0 col7" >Lowest model level zonal wind</td>
#       <td id="T_cd678_row0_col8" class="data row0 col8" >Lowest model level meridional wind</td>
#       <td id="T_cd678_row0_col9" class="data row0 col9" >latitude</td>
#       <td id="T_cd678_row0_col10" class="data row0 col10" >longitude</td>
#     </tr>
#     <tr>
#       <th id="T_cd678_level0_row1" class="row_heading level0 row1" >Description</th>
#       <td id="T_cd678_row1_col0" class="data row1 col0" >The maximum value of the average air temperature recorded at 2 meters above the ground for a given day. It helps track how hot the air was at that height, considering temperature fluctuations during the day.</td>
#       <td id="T_cd678_row1_col1" class="data row1 col1" >The net amount of longwave radiation energy received by the Earth's surface. Longwave radiation refers to infrared radiation, which has a longer wavelength than visible light. The Earth's surface emits longwave radiation, and this flux is a measure of the flow of this radiation. This is important for understanding the Earth's energy balance, as longwave radiation plays a key role in warming the surface and affecting the climate.</td>
#       <td id="T_cd678_row1_col2" class="data row1 col2" >The net amount of solar radiation that reaches the Earth's surface. This flux plays a key role in warming the surface, driving weather patterns, and influencing the climate. The net solar flux accounts for both the incoming solar radiation and the portion that is reflected back into space, typically by clouds, ice, and other reflective surfaces.</td>
#       <td id="T_cd678_row1_col3" class="data row1 col3" >Represents the total rate of precipitation falling from the atmosphere, including both liquid (rain) and ice (snow, sleet) forms, and it accounts for both convective (localized) and large-scale (widespread) weather systems.</td>
#       <td id="T_cd678_row1_col4" class="data row1 col4" ></td>
#       <td id="T_cd678_row1_col5" class="data row1 col5" >Represents the amount of water vapor (in terms of the mixing ratio) in the lowest layer of the atmosphere. It is an important measurement for understanding humidity levels near the Earth's surface, which affects weather patterns like cloud formation, precipitation, and temperature.</td>
#       <td id="T_cd678_row1_col6" class="data row1 col6" >The temperature measured at a standard or reference height in the atmosphere. This is commonly used in climate models or weather forecasts to represent temperature at a specific point in the atmosphere, which helps in understanding temperature profiles and variations with altitude.</td>
#       <td id="T_cd678_row1_col7" class="data row1 col7" >Represents the zonal wind speed and direction at the lowest model level, which is important for understanding surface-level wind patterns, especially in terms of their east-west movement. This wind component influences weather patterns, such as the movement of weather systems across regions.</td>
#       <td id="T_cd678_row1_col8" class="data row1 col8" >Represents the meridional wind speed and direction at the lowest model level, providing information about how wind is moving in the north-south direction near the Earth's surface. This component is important for understanding large-scale atmospheric circulation and weather patterns, including the movement of air masses and systems like the jet stream.</td>
#       <td id="T_cd678_row1_col9" class="data row1 col9" >Measures how far a point is north or south of the equator.</td>
#       <td id="T_cd678_row1_col10" class="data row1 col10" >Measures how far a point is east or west of the Prime Meridian, which is located at 0° longitude.</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Project ideas:

# 1. How do temperature and precipitation patterns correlate across different regions?
# 2. What is the relationship between solar flux and longwave radiation flux at the Earth's surface?
# 3. How does water vapor in the atmosphere (QBOT) relate to temperature and precipitation levels?
# 4. What is the impact of wind patterns (UBOT and VBOT) on temperature and precipitation?
# 5. What is the spatial variation of temperature and wind patterns across latitudes?
# 6. What are the spatial differences in temperature and precipitation during different seasons?

# %%
# Convert time to datetime
import pandas as pd

df['time'] = pd.to_datetime(df['time'])

# %%
# Initial correlation matrix
corr_matrix = df.corr()
print(corr_matrix)
# Out:
#                 time  TREFMXAV_U      FLNS      FSNS     PRECT      PRSN  \
# time        1.000000    0.188005  0.028905  0.063487 -0.017728 -0.031175
# TREFMXAV_U  0.188005    1.000000  0.219688  0.721310 -0.103835 -0.116976
# FLNS        0.028905    0.219688  1.000000  0.683627 -0.473853 -0.059749
# FSNS        0.063487    0.721310  0.683627  1.000000 -0.329469 -0.064145
# PRECT      -0.017728   -0.103835 -0.473853 -0.329469  1.000000  0.117777
# PRSN       -0.031175   -0.116976 -0.059749 -0.064145  0.117777  1.000000
# QBOT        0.157445    0.791619 -0.304497  0.251489  0.213600 -0.078040
# TREFHT      0.177089    0.967620  0.025457  0.605906 -0.026978 -0.123028
# UBOT        0.013412   -0.167388 -0.028396 -0.169522 -0.000641 -0.051850
# VBOT       -0.011024   -0.126361 -0.273296 -0.335963  0.252043 -0.037847
# lat              NaN         NaN       NaN       NaN       NaN       NaN
# lon              NaN         NaN       NaN       NaN       NaN       NaN
#
#                 QBOT    TREFHT      UBOT      VBOT  lat  lon
# time        0.157445  0.177089  0.013412 -0.011024  NaN  NaN
# TREFMXAV_U  0.791619  0.967620 -0.167388 -0.126361  NaN  NaN
# FLNS       -0.304497  0.025457 -0.028396 -0.273296  NaN  NaN
# FSNS        0.251489  0.605906 -0.169522 -0.335963  NaN  NaN
# PRECT       0.213600 -0.026978 -0.000641  0.252043  NaN  NaN
# PRSN       -0.078040 -0.123028 -0.051850 -0.037847  NaN  NaN
# QBOT        1.000000  0.876221 -0.142494  0.023922  NaN  NaN
# TREFHT      0.876221  1.000000 -0.125189 -0.084132  NaN  NaN
# UBOT       -0.142494 -0.125189  1.000000  0.248370  NaN  NaN
# VBOT        0.023922 -0.084132  0.248370  1.000000  NaN  NaN
# lat              NaN       NaN       NaN       NaN  NaN  NaN
# lon              NaN       NaN       NaN       NaN  NaN  NaN

# %% [markdown]
# We can see from this matrix that PRECT & PRSN are not good predictors of TREFMXAV_U.

# %%
# Import necessary package
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Select variables to check for multicollinearity
X = df[['FSNS', 'QBOT']]

# Create VIF dataframe containing these columns
vif_data = pd.DataFrame()
vif_data['feature'] = X.columns

# Calculate VIF for each feature
vif_data['VIF'] = [variance_inflation_factor(X.values, i)
                   for i in range(len(X.columns))]
# Show VIF results
print(vif_data)
# Out:
#   feature       VIF
# 0    FSNS  2.773963
# 1    QBOT  2.773963

# %% [markdown]
# We see here that FSNS (solar flux) and QBOT (water vapour) are not experiencing significant multicollinearity, so can be used together in a regression model

# %%
# Calculate the correlation matrix
correlation_matrix = df[['FSNS', 'QBOT', 'TREFMXAV_U']].corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#                 FSNS      QBOT  TREFMXAV_U
# FSNS        1.000000  0.251489    0.721310
# QBOT        0.251489  1.000000    0.791619
# TREFMXAV_U  0.721310  0.791619    1.000000

# %%
import statsmodels.api as sm

# Define the independent variables and target variable
X = df[['FSNS', 'QBOT']]
y = df['TREFMXAV_U']

# Add a constant term
X = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X).fit()

# Display the summary of the regression results
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             TREFMXAV_U   R-squared:                       0.918
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                 1.528e+05
# Date:                Tue, 04 Feb 2025   Prob (F-statistic):               0.00
# Time:                        13:01:19   Log-Likelihood:                -50018.
# No. Observations:               27374   AIC:                         1.000e+05
# Df Residuals:                   27371   BIC:                         1.001e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        274.5713      0.030   9231.668      0.000     274.513     274.630
# FSNS           0.0390      0.000    311.346      0.000       0.039       0.039
# QBOT        1607.3616      4.418    363.805      0.000    1598.702    1616.022
# ==============================================================================
# Omnibus:                     1129.895   Durbin-Watson:                   0.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1886.926
# Skew:                           0.357   Prob(JB):                         0.00
# Kurtosis:                       4.070   Cond. No.                     5.96e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.96e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# The OLS regression model shows that with an R-squared value of 0.918, 91.8% of the variance is explained by FSNS and QBOT.

# %%
import matplotlib.pyplot as plt

# Scatter plot for FSNS vs. TREFMXAV_U
plt.scatter(x='FSNS', y='TREFMXAV_U', data=df)
plt.title('FSNS vs. TREFMXAV_U')
plt.show()

# Scatter plot for QBOT vs. TREFMXAV_U
plt.scatter(x='QBOT', y='TREFMXAV_U', data=df)
plt.title('QBOT vs. TREFMXAV_U')
plt.show()
